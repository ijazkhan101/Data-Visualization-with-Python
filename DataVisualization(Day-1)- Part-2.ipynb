# %%
# import libraries

import pandas as pd 
import seaborn as sns 
import numpy as np 
import matplotlib.pyplot as plt 


# data set load 
df= pd.read_excel('data_viz.csv')
df


# getting the data view
# Out:
#              timestamp   age        city  weight   height     BMI    salary  \
# 0  2022-12-11 12:48:13  31.0     Karachi    73.0  165.000  26.800   10000.0
# 1  2022-12-11 12:48:15  21.0      Turkey    70.0  170.000  24.900    3000.0
# 2  2022-12-11 12:48:16  41.0  Faisalabad    72.5  156.000  31.200   35000.0
# 3  2022-12-11 12:48:24  22.0  Rawalpindi    75.0  155.000  32.000   50000.0
# 4  2022-12-11 12:48:25  26.0      Harbin    75.0  179.000  23.400   35000.0
# ..                 ...   ...         ...     ...      ...     ...       ...
# 85 2022-12-11 13:01:14  22.0    Mansehra    70.0  173.000  23.400    5000.0
# 86 2022-12-11 13:01:54  36.0  Rawalpindi    86.0  165.000  14.300  105000.0
# 87 2022-12-11 13:03:22  20.0   Islamabad    54.6  162.800  20.600   35000.0
# 88 2022-12-11 13:04:28  32.0     Karachi    67.0  147.402  24.363    3000.0
# 89 2022-12-11 13:05:05  55.0      Jhelum    85.0  160.000  33.200  100000.0
#
# ...

# %%
# check employment_status in the dataset
sns.countplot(x=df['employment_status'])
# Out:
# <AxesSubplot:xlabel='employment_status', ylabel='count'>

# %%
#How to make categorical Plot boxen

sns.catplot(data=df, x='gender' ,y='age', hue="qualification", kind='boxen')

# %%
#How to make categorical Plot bar

sns.catplot(data=df, x='gender' ,y='age', hue="qualification", kind='bar')

# %%
#How to make categorical Plot violin

sns.catplot(data=df, x='gender' ,y='age', hue="qualification", kind='violin', color="green", col="gender")

# %%
#How to make categorical Plot swarm

sns.catplot(data=df, x='gender' ,y='age', hue="employment_status", kind='violin', color="green", col="gender")

sns.swarmplot(data=df, x="gender",y="employment_status", size=3)
# Out:
# <AxesSubplot:title={'center':'gender = Female'}, xlabel='gender', ylabel='employment_status'>

# %%
#boxenplot 

sns.boxenplot(data=df, x='gender',y='age')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='age'>

# %%
#boxenplot 

sns.catplot(data=df, x='gender',y='age',kind="box",showmeans=True)

# %%
sns.catplot(data=df, x="gender",y='salary',kind='bar',capsize=0.1,ci=95,col='qualification')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16340\1152850208.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.catplot(data=df, x="gender",y='salary',kind='bar',capsize=0.1,ci=95,col='qualification')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   timestamp            90 non-null     datetime64[ns]
#  1   age                  90 non-null     float64
#  2   city                 90 non-null     object
#  3   weight               90 non-null     float64
#  4   height               90 non-null     float64
#  5   BMI                  89 non-null     float64
#  6   salary               90 non-null     float64
#  7   gender               90 non-null     object
#  8   qualification        90 non-null     object
#  9   employment_status    90 non-null     object
#  10  covid_vaccine        90 non-null     object
#  11  marital_status       90 non-null     object
#  12  github_copilot_user  90 non-null     object
#  13  favourite_dish       90 non-null     object
# dtypes: datetime64[ns](1), float64(5), object(8)
# ...

# %%
sns.catplot(data=df, x="employment_status",y='salary',kind='bar',capsize=0.1,ci=95,col='favourite_dish')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16340\2857707179.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.catplot(data=df, x="employment_status",y='salary',kind='bar',capsize=0.1,ci=95,col='favourite_dish')
